# %%
import random

user=int(input("Enter your choice,0 for rock,1 for paper or 2 for scissor:"))
computer=random.randint(0, 2)
print(f"computer choice:{computer}")
if user==0 and computer==2:
    print("you win")
elif user==2 and computer==1 :
    print("you win")
elif user==0 and computer==2 :
    print("you win")
elif user==0 and computer==0:
    print("Both choice is same so play again")
elif user==1 and computer==1:
    print("Both choice is same so play again")
elif user==2 and computer==2:
    print("Both choice is same so play again")
else:
    print("Computer win")
print("Want to play again??")
# Out:
# Enter your choice,0 for rock,1 for paper or 2 for scissor:2
# computer choice:1
# you win
# Want to play again??
